# %% [markdown]
# # Exploratory data analysis in Python

# %% [markdown]
# ### About Exploratory Data Analysis
#
# Exploratory Data Analysis refers to the critical process of performing initial investigations on data so as to discover patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and graphical representations. EDA is an approach/philosophy for data analysis that employs a variety of techniques (mostly graphical) to
# * maximize insight into a data set
# * uncover underlying structure
# * extract important variables
# * detect outliers and anomalies
# * test underlying assumptions
# * develop parsimonious models and
# * determine optimal factor settings.

# %% [markdown]
# ## 1.Importing the Required Libraries and dataset

# %%
# including necessary modules such as pandas, matplotlib, seaborn and numpy
import pandas as pd
import numpy as np
# for visualisation
import seaborn as sns                       
import matplotlib.pyplot as plt

# %%
pwd # getting current path of directory
# Out:
# u'C:\\Users\\User-Pc\\Desktop\\ML'

# %% [markdown]
# ### 1.1 Loading the data into the data frame.

# %%
#reading csv file
car_data=pd.read_csv("C:\\Users\\User-Pc\\Desktop\\ML\data.csv")

# %%
# printing first five enteries
car_data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %% [markdown]
# ### 1.2 Checking the types of data and basic summary stats
# It is very important to check whether the data with which we are dealing either has null values or not whether the data is categorical or whether checking duplicacy of data. Moreover, we also need to check whether the target variable MSRP or Price is stored as a string or not. If stored as a string then we need convert that string to the integer data only then we can plot the data via a graph.

# %%
c_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
# Make                11914 non-null object
# Model               11914 non-null object
# Year                11914 non-null int64
# Engine Fuel Type    11911 non-null object
# HP                  11845 non-null float64
# Cylinders           11884 non-null float64
# Transmission        11914 non-null object
# Drive Mode          11914 non-null object
# Number of Doors     11908 non-null float64
# Market Category     8172 non-null object
# Vehicle Size        11914 non-null object
# Vehicle Style       11914 non-null object
# MPG-H               11914 non-null int64
# MPG-C               11914 non-null int64
# Popularity          11914 non-null int64
# Price               11914 non-null int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.5+ MB

# %%
# getting statistics related to car_data
c_data.describe()
# Out:
#                Year           HP     Cylinders  Number of Doors         MPG-H  \
# count  11914.000000  11845.00000  11884.000000     11908.000000  11914.000000
# mean    2010.384338    249.38607      5.628829         3.436093     26.637485
# std        7.579740    109.19187      1.780559         0.881315      8.863001
# min     1990.000000     55.00000      0.000000         2.000000     12.000000
# 25%     2007.000000    170.00000      4.000000         2.000000     22.000000
# 50%     2015.000000    227.00000      6.000000         4.000000     26.000000
# 75%     2016.000000    300.00000      6.000000         4.000000     30.000000
# max     2017.000000   1001.00000     16.000000         4.000000    354.000000
#
#               MPG-C    Popularity         Price
# count  11914.000000  11914.000000  1.191400e+04
# mean      19.733255   1554.911197  4.059474e+04
# std        8.987798   1441.855347  6.010910e+04
# min        7.000000      2.000000  2.000000e+03
# 25%       16.000000    549.000000  2.100000e+04
# 50%       18.000000   1385.000000  2.999500e+04
# 75%       22.000000   2009.000000  4.223125e+04
# max      137.000000   5657.000000  2.065902e+06

# %% [markdown]
# ## 2. Dropping irrelevant columns
# This is a very important step since  there would be columns that we never use and in such cases dropping is useful. Now dropping Market Category is useful since it has more than 40% data missing and dropping no. of doors as well since it is less relevant

# %%
# dropping Market Category since it has more than 40% data missing and dropping no. of doors as well since it is less relevant
c_data=c_data.drop(['Market Category', 'Number of Doors'],axis=1)
c_data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type     HP  Cylinders  \
# 0  BMW  1 Series M  2011  premium unleaded (required)  335.0        6.0
# 1  BMW    1 Series  2011  premium unleaded (required)  300.0        6.0
# 2  BMW    1 Series  2011  premium unleaded (required)  300.0        6.0
# 3  BMW    1 Series  2011  premium unleaded (required)  230.0        6.0
# 4  BMW    1 Series  2011  premium unleaded (required)  230.0        6.0
#
#   Transmission        Drive Mode Vehicle Size Vehicle Style  MPG-H  MPG-C  \
# 0       MANUAL  rear wheel drive      Compact         Coupe     26     19
# 1       MANUAL  rear wheel drive      Compact   Convertible     28     19
# 2       MANUAL  rear wheel drive      Compact         Coupe     28     20
# 3       MANUAL  rear wheel drive      Compact         Coupe     28     18
# 4       MANUAL  rear wheel drive      Compact   Convertible     28     18
#
#    Popularity  Price
# 0        3916  46135
# 1        3916  40650
# 2        3916  36350
# 3        3916  29450
# 4        3916  34500

# %%
# finding out not null values in column Cylinders
c_data.Cylinders.notnull()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#          ...
# 11884    True
# 11885    True
# 11886    True
# 11887    True
# 11888    True
# 11889    True
# 11890    True
# 11891    True
# 11892    True
# 11893    True
# 11894    True
# 11895    True
# 11896    True
# 11897    True
# 11898    True
# 11899    True
# 11900    True
# 11901    True
# 11902    True
# 11903    True
# 11904    True
# 11905    True
# 11906    True
# 11907    True
# 11908    True
# 11909    True
# 11910    True
# 11911    True
# 11912    True
# 11913    True
# Name: Cylinders, Length: 11914, dtype: bool

# %%
c_data["Drive Mode"].notnull()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#          ...
# 11884    True
# 11885    True
# 11886    True
# 11887    True
# 11888    True
# 11889    True
# 11890    True
# 11891    True
# 11892    True
# 11893    True
# 11894    True
# 11895    True
# 11896    True
# 11897    True
# 11898    True
# 11899    True
# 11900    True
# 11901    True
# 11902    True
# 11903    True
# 11904    True
# 11905    True
# 11906    True
# 11907    True
# 11908    True
# 11909    True
# 11910    True
# 11911    True
# 11912    True
# 11913    True
# Name: Drive Mode, Length: 11914, dtype: bool

# %%
# Finding out duplicate values
c_data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14        True
# 15       False
# 16       False
# 17       False
# 18        True
# 19       False
# 20        True
# 21       False
# 22       False
# 23       False
# 24        True
# 25        True
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 11884    False
# 11885    False
# 11886    False
# 11887    False
# 11888    False
# 11889    False
# 11890    False
# 11891    False
# 11892    False
# 11893    False
# 11894    False
# 11895    False
# 11896    False
# 11897    False
# 11898    False
# 11899    False
# 11900    False
# 11901    False
# 11902    False
# 11903    False
# 11904    False
# 11905    False
# 11906    False
# 11907    False
# 11908    False
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %% [markdown]
# ## 3. Renaming the columns

# %%
# Renaming the columns and storing the data in c_data
c_data=car_data.rename(columns={"Engine HP": "HP", "Engine Cylinders": "Cylinders", "Transmission Type": "Transmission", "Driven_Wheels": "Drive Mode", "highway MPG": "MPG-H", "city mpg": "MPG-C", "MSRP": "Price"})

# %%
c_data.head(3)
# Out:
#   Make       Model  Year             Engine Fuel Type     HP  Cylinders  \
# 0  BMW  1 Series M  2011  premium unleaded (required)  335.0        6.0
# 1  BMW    1 Series  2011  premium unleaded (required)  300.0        6.0
# 2  BMW    1 Series  2011  premium unleaded (required)  300.0        6.0
#
#   Transmission        Drive Mode  Number of Doors  \
# 0       MANUAL  rear wheel drive              2.0
# 1       MANUAL  rear wheel drive              2.0
# 2       MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  MPG-H  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe     26
# 1                     Luxury,Performance      Compact   Convertible     28
# 2                Luxury,High-Performance      Compact         Coupe     28
#
#    MPG-C  Popularity  Price
# 0     19        3916  46135
# 1     19        3916  40650
# 2     20        3916  36350

# %%
## Showing duplicate data
c_data[c_data.duplicated()]
# Out:
#            Make                  Model  Year             Engine Fuel Type  \
# 14          BMW               1 Series  2013  premium unleaded (required)
# 18         Audi                    100  1992             regular unleaded
# 20         Audi                    100  1992             regular unleaded
# 24         Audi                    100  1993             regular unleaded
# 25         Audi                    100  1993             regular unleaded
# 88       Nissan                  200SX  1996             regular unleaded
# 92       Nissan                  200SX  1997             regular unleaded
# 94       Nissan                  200SX  1998             regular unleaded
# 109       Volvo                    240  1992             regular unleaded
# 126         BMW  3 Series Gran Turismo  2015  premium unleaded (required)
# 137         BMW               3 Series  2015  premium unleaded (required)
# 141         BMW               3 Series  2015  premium unleaded (required)
# 252       Mazda                    323  1992             regular unleaded
# 413         BMW    4 Series Gran Coupe  2015  premium unleaded (required)
# 414         BMW    4 Series Gran Coupe  2015  premium unleaded (required)
# 431         BMW               4 Series  2015  premium unleaded (required)
# 432         BMW               4 Series  2015  premium unleaded (required)
# 435         BMW               4 Series  2015  premium unleaded (required)
# 436         BMW               4 Series  2015  premium unleaded (required)
# 677     Pontiac                   6000  1990             regular unleaded
# 741       Volvo                    740  1990             regular unleaded
# 742       Volvo                    740  1990             regular unleaded
# 753       Volvo                    740  1992             regular unleaded
# 775       Volvo                    850  1995             regular unleaded
# 778       Volvo                    850  1995             regular unleaded
# 783       Volvo                    850  1996             regular unleaded
# 787       Volvo                    850  1996             regular unleaded
# 788       Volvo                    850  1996             regular unleaded
# 789       Volvo                    850  1996             regular unleaded
# 901        Saab                    900  1997             regular unleaded
# ...         ...                    ...   ...                          ...
# 11196       GMC                Vandura  1994             regular unleaded
# 11198       GMC                Vandura  1994             regular unleaded
# 11202       GMC                Vandura  1995             regular unleaded
# 11203       GMC                Vandura  1995             regular unleaded
# 11219   Hyundai               Veloster  2014             regular unleaded
# 11221   Hyundai               Veloster  2014             regular unleaded
# 11223   Hyundai               Veloster  2014             regular unleaded
# 11224   Hyundai               Veloster  2014             regular unleaded
# 11225   Hyundai               Veloster  2014             regular unleaded
# 11227   Hyundai               Veloster  2014             regular unleaded
# 11228   Hyundai               Veloster  2014             regular unleaded
# 11232   Hyundai               Veloster  2015             regular unleaded
# 11240   Hyundai               Veloster  2016             regular unleaded
# 11241   Hyundai               Veloster  2016             regular unleaded
# 11244   Hyundai               Veloster  2016             regular unleaded
# 11245   Hyundai               Veloster  2016             regular unleaded
# 11375     Acura                  Vigor  1992             regular unleaded
# 11377     Acura                  Vigor  1993             regular unleaded
# 11379     Acura                  Vigor  1994             regular unleaded
# 11383     Dodge                  Viper  2015  premium unleaded (required)
# 11388     Dodge                  Viper  2016  premium unleaded (required)
# 11392     Dodge                  Viper  2017  premium unleaded (required)
# 11421  Plymouth                Voyager  1998             regular unleaded
# 11464    Subaru                    WRX  2016  premium unleaded (required)
# 11471    Subaru                    WRX  2017  premium unleaded (required)
# 11481    Suzuki                   X-90  1998             regular unleaded
# 11603     Volvo                   XC60  2017             regular unleaded
# 11604     Volvo                   XC60  2017             regular unleaded
# 11708    Suzuki                    XL7  2008             regular unleaded
# 11717    Suzuki                    XL7  2008             regular unleaded
#
#           HP  Cylinders      Transmission         Drive Mode  Number of Doors  \
# 14     230.0        6.0            MANUAL   rear wheel drive              2.0
# 18     172.0        6.0            MANUAL  front wheel drive              4.0
# 20     172.0        6.0            MANUAL  front wheel drive              4.0
# 24     172.0        6.0            MANUAL  front wheel drive              4.0
# 25     172.0        6.0            MANUAL  front wheel drive              4.0
# 88     115.0        4.0            MANUAL  front wheel drive              2.0
# 92     115.0        4.0            MANUAL  front wheel drive              2.0
# 94     115.0        4.0            MANUAL  front wheel drive              2.0
# 109    114.0        4.0            MANUAL   rear wheel drive              4.0
# 126    240.0        4.0         AUTOMATIC    all wheel drive              4.0
# 137    240.0        4.0         AUTOMATIC    all wheel drive              4.0
# 141    240.0        4.0         AUTOMATIC   rear wheel drive              4.0
# 252     82.0        4.0            MANUAL  front wheel drive              2.0
# 413    240.0        4.0         AUTOMATIC   rear wheel drive              4.0
# 414    240.0        4.0         AUTOMATIC    all wheel drive              4.0
# 431    240.0        4.0         AUTOMATIC    all wheel drive              2.0
# 432    240.0        4.0         AUTOMATIC    all wheel drive              2.0
# 435    240.0        4.0         AUTOMATIC   rear wheel drive              2.0
# 436    240.0        4.0         AUTOMATIC   rear wheel drive              2.0
# 677    140.0        6.0         AUTOMATIC  front wheel drive              4.0
# 741    114.0        4.0            MANUAL   rear wheel drive              4.0
# 742    114.0        4.0            MANUAL   rear wheel drive              4.0
# 753    114.0        4.0         AUTOMATIC   rear wheel drive              4.0
# 775    168.0        5.0            MANUAL  front wheel drive              4.0
# 778    168.0        5.0            MANUAL  front wheel drive              4.0
# 783    222.0        5.0         AUTOMATIC  front wheel drive              4.0
# 787    222.0        5.0         AUTOMATIC  front wheel drive              4.0
# 788    168.0        5.0            MANUAL  front wheel drive              4.0
# 789    168.0        5.0            MANUAL  front wheel drive              4.0
# 901    185.0        4.0            MANUAL  front wheel drive              2.0
# ...      ...        ...               ...                ...              ...
# 11196  200.0        6.0         AUTOMATIC   rear wheel drive              3.0
# 11198  165.0        6.0         AUTOMATIC   rear wheel drive              3.0
# 11202  165.0        6.0         AUTOMATIC   rear wheel drive              3.0
# 11203  165.0        6.0         AUTOMATIC   rear wheel drive              3.0
# 11219  132.0        4.0  AUTOMATED_MANUAL  front wheel drive              3.0
# 11221  201.0        4.0            MANUAL  front wheel drive              3.0
# 11223  138.0        4.0            MANUAL  front wheel drive              3.0
# 11224  132.0        4.0  AUTOMATED_MANUAL  front wheel drive              3.0
# 11225  138.0        4.0            MANUAL  front wheel drive              3.0
# 11227  201.0        4.0         AUTOMATIC  front wheel drive              3.0
# 11228  132.0        4.0  AUTOMATED_MANUAL  front wheel drive              3.0
# 11232  132.0        4.0  AUTOMATED_MANUAL  front wheel drive              3.0
# 11240  132.0        4.0  AUTOMATED_MANUAL  front wheel drive              3.0
# 11241  132.0        4.0            MANUAL  front wheel drive              3.0
# 11244  201.0        4.0  AUTOMATED_MANUAL  front wheel drive              3.0
# 11245  201.0        4.0            MANUAL  front wheel drive              3.0
# 11375  176.0        5.0            MANUAL  front wheel drive              4.0
# 11377  176.0        5.0            MANUAL  front wheel drive              4.0
# 11379  176.0        5.0            MANUAL  front wheel drive              4.0
# 11383  645.0       10.0            MANUAL   rear wheel drive              2.0
# 11388  645.0       10.0            MANUAL   rear wheel drive              2.0
# 11392  645.0       10.0            MANUAL   rear wheel drive              2.0
# 11421  150.0        6.0         AUTOMATIC  front wheel drive              4.0
# 11464  305.0        4.0            MANUAL    all wheel drive              4.0
# 11471  305.0        4.0            MANUAL    all wheel drive              4.0
# 11481   95.0        4.0            MANUAL   four wheel drive              2.0
# 11603  302.0        4.0         AUTOMATIC    all wheel drive              4.0
# 11604  240.0        4.0         AUTOMATIC  front wheel drive              4.0
# 11708  252.0        6.0         AUTOMATIC    all wheel drive              4.0
# 11717  252.0        6.0         AUTOMATIC  front wheel drive              4.0
#
#                       Market Category Vehicle Size      Vehicle Style  MPG-H  \
# 14                 Luxury,Performance      Compact              Coupe     28
# 18                             Luxury      Midsize              Sedan     24
# 20                             Luxury      Midsize              Sedan     24
# 24                             Luxury      Midsize              Sedan     24
# 25                             Luxury      Midsize              Sedan     24
# 88                                NaN      Compact              Coupe     36
# 92                                NaN      Compact              Coupe     35
# 94                                NaN      Compact              Coupe     35
# 109                            Luxury      Midsize              Sedan     26
# 126                  Hatchback,Luxury      Midsize      4dr Hatchback     33
# 137                            Luxury      Midsize              Sedan     33
# 141                Luxury,Performance      Midsize              Sedan     35
# 252                         Hatchback      Compact      2dr Hatchback     33
# 413                            Luxury      Midsize              Sedan     34
# 414                            Luxury      Midsize              Sedan     33
# 431                            Luxury      Midsize              Coupe     33
# 432                            Luxury      Midsize        Convertible     33
# 435                            Luxury      Midsize        Convertible     34
# 436                Luxury,Performance      Midsize              Coupe     35
# 677                               NaN      Midsize              Wagon     27
# 741                            Luxury      Midsize              Wagon     26
# 742                            Luxury      Midsize              Sedan     26
# 753                            Luxury      Midsize              Wagon     26
# 775                            Luxury      Midsize              Sedan     26
# 778                            Luxury      Midsize              Wagon     26
# 783                Luxury,Performance      Midsize              Sedan     24
# 787                Luxury,Performance      Midsize              Wagon     24
# 788                            Luxury      Midsize              Sedan     26
# 789                            Luxury      Midsize              Wagon     26
# 901      Hatchback,Luxury,Performance      Compact      2dr Hatchback     25
# ...                               ...          ...                ...    ...
# 11196                             NaN      Midsize          Cargo Van     20
# 11198                             NaN      Compact          Cargo Van     20
# 11202                             NaN      Midsize          Cargo Van     20
# 11203                             NaN      Compact          Cargo Van     20
# 11219                       Hatchback      Compact      2dr Hatchback     36
# 11221           Hatchback,Performance      Compact      2dr Hatchback     33
# 11223                       Hatchback      Compact      2dr Hatchback     35
# 11224                       Hatchback      Compact      2dr Hatchback     36
# 11225                       Hatchback      Compact      2dr Hatchback     35
# 11227           Hatchback,Performance      Compact      2dr Hatchback     31
# 11228                       Hatchback      Compact      2dr Hatchback     36
# 11232                       Hatchback      Compact      2dr Hatchback     36
# 11240                       Hatchback      Compact      2dr Hatchback     36
# 11241                       Hatchback      Compact      2dr Hatchback     35
# 11244           Hatchback,Performance      Compact      2dr Hatchback     33
# 11245           Hatchback,Performance      Compact      2dr Hatchback     33
# 11375                          Luxury      Midsize              Sedan     24
# 11377                          Luxury      Midsize              Sedan     24
# 11379                          Luxury      Midsize              Sedan     24
# 11383         Exotic,High-Performance      Compact              Coupe     21
# 11388         Exotic,High-Performance      Compact              Coupe     21
# 11392         Exotic,High-Performance      Compact              Coupe     19
# 11421                             NaN      Midsize  Passenger Minivan     24
# 11464  Factory Tuner,High-Performance      Compact              Sedan     23
# 11471  Factory Tuner,High-Performance      Compact              Sedan     23
# 11481                             NaN      Compact            2dr SUV     26
# 11603    Crossover,Luxury,Performance      Midsize            4dr SUV     29
# 11604                Crossover,Luxury      Midsize            4dr SUV     30
# 11708                       Crossover      Midsize            4dr SUV     22
# 11717                       Crossover      Midsize            4dr SUV     22
#
#        MPG-C  Popularity  Price
# 14        19        3916  31500
# 18        17        3105   2000
# 20        17        3105   2000
# 24        17        3105   2000
# 25        17        3105   2000
# 88        26        2009   2000
# 92        25        2009   2000
# 94        25        2009   2000
# 109       19         870   2000
# 126       22        3916  41850
# 137       22        3916  39500
# 141       23        3916  37500
# 252       25         586   2000
# 413       23        3916  40300
# 414       22        3916  42300
# 431       22        3916  42750
# 432       21        3916  50750
# 435       23        3916  48750
# 436       23        3916  40750
# 677       17         210   2000
# 741       19         870   2000
# 742       19         870   2000
# 753       18         870   2000
# 775       18         870   2000
# 778       18         870   2000
# 783       17         870   2000
# 787       17         870   2000
# 788       18         870   2000
# 789       18         870   2000
# 901       18         376   2000
# ...      ...         ...    ...
# 11196     15         549   2000
# 11198     15         549   2000
# 11202     15         549   2000
# 11203     15         549   2000
# 11219     28        1439  21650
# 11221     24        1439  22300
# 11223     26        1439  17800
# 11224     28        1439  19050
# 11225     26        1439  17800
# 11227     24        1439  23300
# 11228     28        1439  19050
# 11232     27        1439  21950
# 11240     28        1439  19100
# 11241     27        1439  18000
# 11244     27        1439  23800
# 11245     25        1439  22600
# 11375     18         204   2000
# 11377     18         204   2000
# 11379     18         204   2000
# 11383     12        1851  94995
# 11388     12        1851  95895
# 11392     12        1851  95895
# 11421     17         535   2000
# 11464     17         640  39995
# 11471     17         640  39995
# 11481     22         481   2000
# 11603     20         870  46350
# 11604     23         870  40950
# 11708     15         481  29149
# 11717     16         481  27499
#
# [715 rows x 16 columns]

# %%
mc_data=c_data

# %%
mc_data.head(2)
# Out:
#   Make       Model  Year             Engine Fuel Type     HP  Cylinders  \
# 0  BMW  1 Series M  2011  premium unleaded (required)  335.0        6.0
# 1  BMW    1 Series  2011  premium unleaded (required)  300.0        6.0
#
#   Transmission        Drive Mode  Number of Doors  \
# 0       MANUAL  rear wheel drive              2.0
# 1       MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  MPG-H  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe     26
# 1                     Luxury,Performance      Compact   Convertible     28
#
#    MPG-C  Popularity  Price
# 0     19        3916  46135
# 1     19        3916  40650

# %% [markdown]
# ## 4. Dropping the duplicate rows
# It is very important to remove duplicate values from data set.

# %%
# removing duplicate values
mc_data.drop_duplicates(keep="first", inplace=True)

# %%
mc_data.head(22)
# Out:
#     Make       Model  Year             Engine Fuel Type     HP  Cylinders  \
# 0    BMW  1 Series M  2011  premium unleaded (required)  335.0        6.0
# 1    BMW    1 Series  2011  premium unleaded (required)  300.0        6.0
# 2    BMW    1 Series  2011  premium unleaded (required)  300.0        6.0
# 3    BMW    1 Series  2011  premium unleaded (required)  230.0        6.0
# 4    BMW    1 Series  2011  premium unleaded (required)  230.0        6.0
# 5    BMW    1 Series  2012  premium unleaded (required)  230.0        6.0
# 6    BMW    1 Series  2012  premium unleaded (required)  300.0        6.0
# 7    BMW    1 Series  2012  premium unleaded (required)  300.0        6.0
# 8    BMW    1 Series  2012  premium unleaded (required)  230.0        6.0
# 9    BMW    1 Series  2013  premium unleaded (required)  230.0        6.0
# 10   BMW    1 Series  2013  premium unleaded (required)  300.0        6.0
# 11   BMW    1 Series  2013  premium unleaded (required)  230.0        6.0
# 12   BMW    1 Series  2013  premium unleaded (required)  300.0        6.0
# 13   BMW    1 Series  2013  premium unleaded (required)  230.0        6.0
# 15   BMW    1 Series  2013  premium unleaded (required)  320.0        6.0
# 16   BMW    1 Series  2013  premium unleaded (required)  320.0        6.0
# 17  Audi         100  1992             regular unleaded  172.0        6.0
# 19  Audi         100  1992             regular unleaded  172.0        6.0
# 21  Audi         100  1992             regular unleaded  172.0        6.0
# 22  Audi         100  1993             regular unleaded  172.0        6.0
# 23  Audi         100  1993             regular unleaded  172.0        6.0
# 26  Audi         100  1993             regular unleaded  172.0        6.0
#
#    Transmission         Drive Mode  Number of Doors  \
# 0        MANUAL   rear wheel drive              2.0
# 1        MANUAL   rear wheel drive              2.0
# 2        MANUAL   rear wheel drive              2.0
# 3        MANUAL   rear wheel drive              2.0
# 4        MANUAL   rear wheel drive              2.0
# 5        MANUAL   rear wheel drive              2.0
# 6        MANUAL   rear wheel drive              2.0
# 7        MANUAL   rear wheel drive              2.0
# 8        MANUAL   rear wheel drive              2.0
# 9        MANUAL   rear wheel drive              2.0
# 10       MANUAL   rear wheel drive              2.0
# 11       MANUAL   rear wheel drive              2.0
# 12       MANUAL   rear wheel drive              2.0
# 13       MANUAL   rear wheel drive              2.0
# 15       MANUAL   rear wheel drive              2.0
# 16       MANUAL   rear wheel drive              2.0
# 17       MANUAL  front wheel drive              4.0
# 19    AUTOMATIC    all wheel drive              4.0
# 21       MANUAL    all wheel drive              4.0
# 22       MANUAL  front wheel drive              4.0
# 23    AUTOMATIC    all wheel drive              4.0
# 26       MANUAL    all wheel drive              4.0
#
#                           Market Category Vehicle Size Vehicle Style  MPG-H  \
# 0   Factory Tuner,Luxury,High-Performance      Compact         Coupe     26
# 1                      Luxury,Performance      Compact   Convertible     28
# 2                 Luxury,High-Performance      Compact         Coupe     28
# 3                      Luxury,Performance      Compact         Coupe     28
# 4                                  Luxury      Compact   Convertible     28
# 5                      Luxury,Performance      Compact         Coupe     28
# 6                      Luxury,Performance      Compact   Convertible     26
# 7                 Luxury,High-Performance      Compact         Coupe     28
# 8                                  Luxury      Compact   Convertible     28
# 9                                  Luxury      Compact   Convertible     27
# 10                Luxury,High-Performance      Compact         Coupe     28
# 11                     Luxury,Performance      Compact         Coupe     28
# 12                     Luxury,Performance      Compact   Convertible     28
# 13                                 Luxury      Compact   Convertible     28
# 15                Luxury,High-Performance      Compact   Convertible     25
# 16                Luxury,High-Performance      Compact         Coupe     28
# 17                                 Luxury      Midsize         Sedan     24
# 19                                 Luxury      Midsize         Wagon     20
# 21                                 Luxury      Midsize         Sedan     21
# 22                                 Luxury      Midsize         Sedan     24
# 23                                 Luxury      Midsize         Wagon     20
# 26                                 Luxury      Midsize         Sedan     21
#
#     MPG-C  Popularity  Price
# 0      19        3916  46135
# 1      19        3916  40650
# 2      20        3916  36350
# 3      18        3916  29450
# 4      18        3916  34500
# 5      18        3916  31200
# 6      17        3916  44100
# 7      20        3916  39300
# 8      18        3916  36900
# 9      18        3916  37200
# 10     20        3916  39600
# 11     19        3916  31500
# 12     19        3916  44400
# 13     19        3916  37200
# 15     18        3916  48250
# 16     20        3916  43550
# 17     17        3105   2000
# 19     16        3105   2000
# 21     16        3105   2000
# 22     17        3105   2000
# 23     16        3105   2000
# 26     16        3105   2000

# %% [markdown]
# ### 4.1 Dropping the missing or null values.
# Now in this step all the missing values are detected and are dropped later.

# %%
# printing the no. of null values for each column
print(mc_data.isnull().sum())
# Out:
# Make                   0
# Model                  0
# Year                   0
# Engine Fuel Type       3
# HP                    69
# Cylinders             30
# Transmission           0
# Drive Mode             0
# Number of Doors        6
# Market Category     3376
# Vehicle Size           0
# Vehicle Style          0
# MPG-H                  0
# MPG-C                  0
# Popularity             0
# Price                  0
# dtype: int64

# %%
# drop all rows with null or missing values
mc_data=mc_data.dropna()

# %%
print(mc_data.isnull().sum())
# Out:
# Make                0
# Model               0
# Year                0
# Engine Fuel Type    0
# HP                  0
# Cylinders           0
# Transmission        0
# Drive Mode          0
# Number of Doors     0
# Market Category     0
# Vehicle Size        0
# Vehicle Style       0
# MPG-H               0
# MPG-C               0
# Popularity          0
# Price               0
# dtype: int64

# %%
sns.boxplot?
# Out:
# Signature: sns.boxplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, notch=False, ax=None, **kwargs)
# Docstring:
# Draw a box plot to show distributions with respect to categories.
#
# A box plot (or box-and-whisker plot) shows the distribution of quantitative
# data in a way that facilitates comparisons between variables or across
# levels of a categorical variable. The box shows the quartiles of the
# dataset while the whiskers extend to show the rest of the distribution,
# except for points that are determined to be "outliers" using a method
# that is a function of the inter-quartile range.
#
#
# Input data can be passed in a variety of formats, including:
#
# - Vectors of data represented as lists, numpy arrays, or pandas Series
#   objects passed directly to the ``x``, ``y``, and/or ``hue`` parameters.
# - A "long-form" DataFrame, in which case the ``x``, ``y``, and ``hue``
#   variables will determine how the data are plotted.
# - A "wide-form" DataFrame, such that each numeric column will be plotted.
# - An array or list of vectors.
#
# In most cases, it is possible to use numpy or Python objects, but pandas
# objects are preferable because the associated names will be used to
# annotate the axes. Additionally, you can use Categorical types for the
# grouping variables to control the order of plot elements.
#
# This function always treats one of the variables as categorical and
# draws data at ordinal positions (0, 1, ... n) on the relevant axis, even
# when the data has a numeric or date type.
#
# See the :ref:`tutorial <categorical_tutorial>` for more information.
#
# Parameters
# ----------
# x, y, hue : names of variables in ``data`` or vector data, optional
#     Inputs for plotting long-form data. See examples for interpretation.
# data : DataFrame, array, or list of arrays, optional
#     Dataset for plotting. If ``x`` and ``y`` are absent, this is
#     interpreted as wide-form. Otherwise it is expected to be long-form.
# order, hue_order : lists of strings, optional
#     Order to plot the categorical levels in, otherwise the levels are
#     inferred from the data objects.
# orient : "v" | "h", optional
#     Orientation of the plot (vertical or horizontal). This is usually
#     inferred from the dtype of the input variables, but can be used to
#     specify when the "categorical" variable is a numeric or when plotting
#     wide-form data.
# color : matplotlib color, optional
#     Color for all of the elements, or seed for a gradient palette.
# palette : palette name, list, or dict, optional
#     Colors to use for the different levels of the ``hue`` variable. Should
#     be something that can be interpreted by :func:`color_palette`, or a
#     dictionary mapping hue levels to matplotlib colors.
# saturation : float, optional
#     Proportion of the original saturation to draw colors at. Large patches
#     often look better with slightly desaturated colors, but set this to
#     ``1`` if you want the plot colors to perfectly match the input color
#     spec.
# width : float, optional
#     Width of a full element when not using hue nesting, or width of all the
#     elements for one level of the major grouping variable.
# dodge : bool, optional
#     When hue nesting is used, whether elements should be shifted along the
#     categorical axis.
# fliersize : float, optional
#     Size of the markers used to indicate outlier observations.
# linewidth : float, optional
#     Width of the gray lines that frame the plot elements.
# whis : float, optional
#     Proportion of the IQR past the low and high quartiles to extend the
#     plot whiskers. Points outside this range will be identified as
#     outliers.
# notch : boolean, optional
#     Whether to "notch" the box to indicate a confidence interval for the
#     median. There are several other parameters that can control how the
#     notches are drawn; see the ``plt.boxplot`` help for more information
#     on them.
# ax : matplotlib Axes, optional
#     Axes object to draw the plot onto, otherwise uses the current Axes.
# kwargs : key, value mappings
#     Other keyword arguments are passed through to ``plt.boxplot`` at draw
#     time.
#
# Returns
# -------
# ax : matplotlib Axes
#     Returns the Axes object with the plot drawn onto it.
#
# See Also
# --------
# violinplot : A combination of boxplot and kernel density estimation.
# stripplot : A scatterplot where one variable is categorical. Can be used
#             in conjunction with other plots to show each observation.
# swarmplot : A categorical scatterplot where the points do not overlap. Can
#             be used with other plots to show each observation.
#
# Examples
# --------
#
# Draw a single horizontal boxplot:
#
# .. plot::
#     :context: close-figs
#
#     >>> import seaborn as sns
#     >>> sns.set(style="whitegrid")
#     >>> tips = sns.load_dataset("tips")
#     >>> ax = sns.boxplot(x=tips["total_bill"])
#
# Draw a vertical boxplot grouped by a categorical variable:
#
# .. plot::
#     :context: close-figs
#
#     >>> ax = sns.boxplot(x="day", y="total_bill", data=tips)
#
# Draw a boxplot with nested grouping by two categorical variables:
#
# .. plot::
#     :context: close-figs
#
#     >>> ax = sns.boxplot(x="day", y="total_bill", hue="smoker",
#     ...                  data=tips, palette="Set3")
#
# Draw a boxplot with nested grouping when some bins are empty:
#
# .. plot::
#     :context: close-figs
#
#     >>> ax = sns.boxplot(x="day", y="total_bill", hue="time",
#     ...                  data=tips, linewidth=2.5)
#
# Control box order by passing an explicit order:
#
# .. plot::
#     :context: close-figs
#
#     >>> ax = sns.boxplot(x="time", y="tip", data=tips,
#     ...                  order=["Dinner", "Lunch"])
#
# Draw a boxplot for each numeric variable in a DataFrame:
#
# .. plot::
#     :context: close-figs
#
#     >>> iris = sns.load_dataset("iris")
#     >>> ax = sns.boxplot(data=iris, orient="h", palette="Set2")
#
# Use ``hue`` without changing box position or width:
#
# .. plot::
#     :context: close-figs
#
#     >>> tips["weekend"] = tips["day"].isin(["Sat", "Sun"])
#     >>> ax = sns.boxplot(x="day", y="total_bill", hue="weekend",
#     ...                  data=tips, dodge=False)
#
# Use :func:`swarmplot` to show the datapoints on top of the boxes:
#
# .. plot::
#     :context: close-figs
#
#     >>> ax = sns.boxplot(x="day", y="total_bill", data=tips)
#     >>> ax = sns.swarmplot(x="day", y="total_bill", data=tips, color=".25")
#
# Use :func:`catplot` to combine a :func:`pointplot` and a
# :class:`FacetGrid`. This allows grouping within additional categorical
# variables. Using :func:`catplot` is safer than using :class:`FacetGrid`
# directly, as it ensures synchronization of variable order across facets:
#
# .. plot::
#     :context: close-figs
#
#     >>> g = sns.catplot(x="sex", y="total_bill",
#     ...                 hue="smoker", col="time",
#     ...                 data=tips, kind="box",
#     ...                 height=4, aspect=.7);
# File:      c:\users\user-pc\anaconda2\lib\site-packages\seaborn\categorical.py
# Type:      function

# %% [markdown]
# ## 5. Detecting Outliers
# An outlier is an observation that lies an abnormal distance from other values in a random sample from a population. In a sense, this definition leaves it up to the analyst (or a consensus process) to decide what will be considered abnormal. Before abnormal observations can be singled out, it is necessary to characterize normal observations.

# %%
# Detecting outliers in column HP using box-plot
sns.boxplot(x="HP", data=mc_data)

# %%
# Detecting outliers in column Cylinders using box-plot
sns.boxplot(x="Cylinders", data=mc_data)

# %%
# Detecting outliers in column MPG-H using box-plot
sns.boxplot(x="MPG-H", data=mc_data)

# %%
# Detecting outliers in column Price using box-plot
sns.boxplot(x="Price", data=mc_data)

# %%
q1 = mc_data.quantile(0.25)
q3 = mc_data.quantile(0.75)
iqr = q3 - q1
iqr
# Out:
# Year                   6.0
# HP                   131.0
# Cylinders              2.0
# Number of Doors        2.0
# MPG-H                  8.0
# MPG-C                  6.0
# Popularity          1489.0
# Price              23252.5
# dtype: float64

# %%
mc_data = mc_data[~((mc_data < (q1 - 1.5*iqr)) | (mc_data > (q3 + 1.5*iqr))) .any(axis=1)]
mc_data.shape
# Out:
# (5622, 16)

# %% [markdown]
# ## 6. Top Car brands

# %%
# Percentage of car per brand
count_car = mc_data["Make"].value_counts()*100/sum(mc_data["Make"].value_counts())

# Top 10 car brands
popular_labels = count_car.index[:10]
    
# Plot
plt.figure(figsize=(10,5))
plt.barh(popular_labels, width=count_car[:10], color="red")
plt.xlabel("Proportion")
plt.ylabel("Car brand")
plt.title('Top 10 Car brands')
plt.show()

# %%
prices = mc_data[['Make','Price']].loc[(mc_data['Make'] == 'Chevrolet')|
               (mc_data['Make'] == 'Ford')|
               (mc_data['Make'] == 'Volkswagen')|
               (mc_data['Make'] == 'Toyota')|
               (mc_data['Make'] == 'Dodge')|
               (mc_data['Make'] == 'Nissan')|
               (mc_data['Make'] == 'GMC')|
               (mc_data['Make'] == 'Honda')|
               (mc_data['Make'] == 'Mazda')].groupby('Make').mean()
print(prices)
# Out:
#                    Price
# Make
# Chevrolet   34804.256140
# Dodge       30237.995868
# GMC         37863.725564
# Honda       29311.985294
# Mazda       25898.916256
# Nissan      33645.876866
# Toyota      32619.345794
# Volkswagen  30344.291444

# %% [markdown]
# ## 7.Correlation Matrix

# %%
mc_data.corr()
# Out:
#                      Year        HP  Cylinders  Number of Doors     MPG-H  \
# Year             1.000000  0.151051  -0.173957         0.121819  0.344971
# HP               0.151051  1.000000   0.772090        -0.038800 -0.558102
# Cylinders       -0.173957  0.772090   1.000000        -0.002469 -0.709868
# Number of Doors  0.121819 -0.038800  -0.002469         1.000000 -0.045712
# MPG-H            0.344971 -0.558102  -0.709868        -0.045712  1.000000
# MPG-C            0.320515 -0.646821  -0.749259         0.003745  0.924245
# Popularity       0.194030  0.089515   0.021924        -0.098174  0.109159
# Price            0.224195  0.757838   0.518301         0.015691 -0.308098
#
#                     MPG-C  Popularity     Price
# Year             0.320515    0.194030  0.224195
# HP              -0.646821    0.089515  0.757838
# Cylinders       -0.749259    0.021924  0.518301
# Number of Doors  0.003745   -0.098174  0.015691
# MPG-H            0.924245    0.109159 -0.308098
# MPG-C            1.000000    0.062135 -0.381777
# Popularity       0.062135    1.000000  0.141315
# Price           -0.381777    0.141315  1.000000

# %% [markdown]
# ### Finding out High correlation
# * Between HP and Cylinders
# * Between HP and Price
# * Between MPG-H and MPG-C
#
# So from above, we can conclude that higher is HP more cylinders will be there in car due to positive correlation.
# Same applies to HP and Price, MPG-H and MPG-C as well

# %% [markdown]
# ## Finding out AntiCorrelation
# * Between Cylinders and MPG-H
# * Between Cylinders and MPG-C
#
# So from above, we can conclude that higher is MPG-H less cylinders will be there in car due to negative correlation. Same applies to MPG-C and cylinders as well

# %%
plt.figure(figsize=(10,5))
c= mc_data.corr()
sns.heatmap(c,cmap="RdYlGn",annot=True)

# %% [markdown]
# ## 8.Scatter Plot
# We generally use scatter plots to find the correlation between two variables. Here the scatter plots are plotted between Horsepower and Price and we can see the plot below. With the plot given below, we can easily draw a trend line.

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.scatter(mc_data['HP'], mc_data['Price'],color="Red")
ax.set_xlabel('HP')
ax.set_ylabel('Price')
plt.show()
